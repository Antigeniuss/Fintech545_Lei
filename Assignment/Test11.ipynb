# %%
import Utils
import pandas as pd
import numpy as np

# %%
returns = pd.read_csv("../testfiles/data/test11_1_returns.csv")
init_weights = pd.read_csv("../testfiles/data/test11_1_weights.csv").values.flatten()

Utils.asset_attribution(returns,init_weights)
# Out:
#                        Value        x1        x2        x3  Portfolio
# 0                TotalReturn -0.221446 -0.016008  0.301467   0.081098
# 1         Return Attribution -0.065513 -0.002220  0.148831   0.081098
# 2  Vol Attribution (beta·σp) -0.000620  0.002827  0.012580   0.014787

# %%
asset_returns = pd.read_csv("../testfiles/data/test11_2_stock_returns.csv")
betas = pd.read_csv("../testfiles/data/test11_2_beta.csv", index_col=0)
init_weights = pd.read_csv("../testfiles/data/test11_2_weights.csv")
factor_returns = pd.read_csv("../testfiles/data/test11_2_factor_returns.csv")

Utils.factor_attribution(asset_returns, betas, init_weights, factor_returns)
# Out:
#                 Value        F1        F2        F3     Alpha  Portfolio
# 0         TotalReturn  0.079939  0.026711 -0.016317  0.046443   0.105327
# 1  Return Attribution  0.065173  0.000174 -0.007579  0.047559   0.105327
# 2     Vol Attribution  0.005013 -0.000009  0.001785  0.005445   0.012234
